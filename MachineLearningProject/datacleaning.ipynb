# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
data=pd.read_csv(r"C:\Users\Ravin\Downloads\survey.csv")
# understanding the data
data.describe()
# Out:
#                 Age
# count  1.259000e+03
# mean   7.942815e+07
# std    2.818299e+09
# min   -1.726000e+03
# 25%    2.700000e+01
# 50%    3.100000e+01
# 75%    3.600000e+01
# max    1.000000e+11

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1259 entries, 0 to 1258
# Data columns (total 27 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Timestamp                  1259 non-null   object
#  1   Age                        1259 non-null   int64
#  2   Gender                     1259 non-null   object
#  3   Country                    1259 non-null   object
#  4   state                      744 non-null    object
#  5   self_employed              1241 non-null   object
#  6   family_history             1259 non-null   object
#  7   treatment                  1259 non-null   object
#  8   work_interfere             995 non-null    object
#  9   no_employees               1259 non-null   object
#  10  remote_work                1259 non-null   object
#  11  tech_company               1259 non-null   object
#  12  benefits                   1259 non-null   object
# ...

# %%
data.columns
# Out:
# Index(['Timestamp', 'Age', 'Gender', 'Country', 'state', 'self_employed',
#        'family_history', 'treatment', 'work_interfere', 'no_employees',
#        'remote_work', 'tech_company', 'benefits', 'care_options',
#        'wellness_program', 'seek_help', 'anonymity', 'leave',
#        'mental_health_consequence', 'phys_health_consequence', 'coworkers',
#        'supervisor', 'mental_health_interview', 'phys_health_interview',
#        'mental_vs_physical', 'obs_consequence', 'comments'],
#       dtype='object')

# %%
def clean_gender(gender):
    gender = str(gender).strip().lower()
    if gender.startswith("m"):
        return "Male"
    elif gender.startswith("f"):
        return "Female"
    else:
        return "Other"
data["Gender"]=data["Gender"].apply(clean_gender)
print(data["Gender"].value_counts())
# Out:
# Gender
# Male      988
# Female    244
# Other      27
# Name: count, dtype: int64

# %%
print(data.isnull().sum())
# Handling of columns having null values
data['state']=data['state'].fillna("Not Verified")
# Out:
# Timestamp                       0
# Age                             0
# Gender                          0
# Country                         0
# state                         515
# self_employed                  18
# family_history                  0
# treatment                       0
# work_interfere                264
# no_employees                    0
# remote_work                     0
# tech_company                    0
# benefits                        0
# care_options                    0
# wellness_program                0
# seek_help                       0
# anonymity                       0
# leave                           0
# mental_health_consequence       0
# phys_health_consequence         0
# coworkers                       0
# supervisor                      0
# mental_health_interview         0
# phys_health_interview           0
# mental_vs_physical              0
# obs_consequence                 0
# comments                     1095
# dtype: int64

# %%
data['self_employed']=data['self_employed'].fillna("Not Verified employed")
data['work_interfere']=data['work_interfere'].fillna("Not Verified")
data.isnull().sum()
# Out:
# Timestamp                       0
# Age                             0
# Gender                          0
# Country                         0
# state                           0
# self_employed                   0
# family_history                  0
# treatment                       0
# work_interfere                  0
# no_employees                    0
# remote_work                     0
# tech_company                    0
# benefits                        0
# care_options                    0
# wellness_program                0
# seek_help                       0
# anonymity                       0
# leave                           0
# mental_health_consequence       0
# phys_health_consequence         0
# coworkers                       0
# supervisor                      0
# mental_health_interview         0
# phys_health_interview           0
# mental_vs_physical              0
# obs_consequence                 0
# comments                     1095
# dtype: int64

# %%
data.to_csv(r"C:\Users\Ravin\Downloads\updated1_survey.csv")
#print(data.head())
new_data=pd.read_csv(r"C:\Users\Ravin\Downloads\updated1_survey.csv")
print(new_data.isnull().sum())
# Out:
# Unnamed: 0                      0
# Timestamp                       0
# Age                             0
# Gender                          0
# Country                         0
# state                           0
# self_employed                   0
# family_history                  0
# treatment                       0
# work_interfere                  0
# no_employees                    0
# remote_work                     0
# tech_company                    0
# benefits                        0
# care_options                    0
# wellness_program                0
# seek_help                       0
# anonymity                       0
# leave                           0
# mental_health_consequence       0
# phys_health_consequence         0
# coworkers                       0
# supervisor                      0
# mental_health_interview         0
# phys_health_interview           0
# mental_vs_physical              0
# obs_consequence                 0
# ...

# %% [markdown]
# Data Analysis

# %%
# Data Anlaysis is our second tep to understand data

# %%
data['Gender'].value_counts()
# Out:
# Gender
# Male      988
# Female    244
# Other      27
# Name: count, dtype: int64

# %%
values=new_data['Gender'].value_counts()
index=values.index
plt.pie(values,labels=index,startangle=90,autopct='%1.1f%%')
plt.title("Gender Distribution")
plt.legend()
plt.show()

# %%
values=new_data['Country'].value_counts().head(5)
index=values.index
plt.bar(index,values)
plt.title("Country Distribution among people")
plt.show()

# %%
values=new_data['state'].value_counts().head(10)
index=values.index
plt.pie(values, labels=index,startangle=90,autopct='%1.1f%%')
plt.title("State Distribution")
plt.legend()
plt.show()

# %%
values=new_data['self_employed'].value_counts()
index=values.index
plt.pie(values,labels=index,startangle=90,autopct='%1.1f%%')
plt.title("Self Employed Distribution")
plt.legend()
plt.show()

# %%
values=new_data['family_history'].value_counts()
index=values.index
plt.pie(values,labels=index,startangle=90,autopct='%1.1f%%')
plt.title("Family History Distribution")
plt.legend()
plt.show()

# %%
values=new_data['treatment'].value_counts()
index=values.index
plt.pie(values,labels=index,startangle=90,autopct='%1.1f%%')
plt.title("Treatment History Distribution")
plt.legend()
plt.show()

# %%
data['work_interfere'].value_counts()
values=new_data['work_interfere'].value_counts()
index=values.index
plt.pie(values, labels=index, startangle=90, autopct='%1.1f%%')
plt.title("Work Interfere Distribution")
plt.legend()
plt.show()

# %%
values=new_data['no_employees'].value_counts()
index=values.index
plt.barh(index, values, color='blue')
plt.title("Work Interfere Distribution")
plt.xlabel("No of Employees")
plt.ylabel("Count")
plt.show()

# %%
# using heatmap to identify features
from sklearn.preprocessing import LabelEncoder
data=pd.read_csv(r"C:\Users\Ravin\Downloads\updated1_survey.csv")
# Dropping useless column
data.drop(['Unnamed: 0','comments'],axis=1,inplace=True)
features_to_convert=['Age','Gender','Country','state', 'self_employed','family_history','treatment','work_interfere', 'no_employees','remote_work','tech_company','benefits', 'care_options']
encoder=LabelEncoder()
for feature in features_to_convert:
    data[feature]=encoder.fit_transform(data[feature])

# %%
plt.figure(figsize=(10, 6))
correlation_matrix=data.corr(numeric_only=True)
sns.heatmap(correlation_matrix,annot=True,cmap='coolwarm', linewidths=0.9, fmt=".2f")
plt.title("Correlation Matrix")
plt.tight_layout()
plt.show()

# %%
data=pd.read_csv(r'C:\Users\Ravin\Downloads\updated1_survey.csv')
data.info()
data.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1259 entries, 0 to 1258
# Data columns (total 28 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Unnamed: 0                 1259 non-null   int64
#  1   Timestamp                  1259 non-null   object
#  2   Age                        1259 non-null   int64
#  3   Gender                     1259 non-null   object
#  4   Country                    1259 non-null   object
#  5   state                      1259 non-null   object
#  6   self_employed              1259 non-null   object
#  7   family_history             1259 non-null   object
#  8   treatment                  1259 non-null   object
#  9   work_interfere             1259 non-null   object
#  10  no_employees               1259 non-null   object
#  11  remote_work                1259 non-null   object
#  12  tech_company               1259 non-null   object
# ...
